# %% [markdown]
# # Introduction to matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[2,4,6,8]
plt.plot(x,y);

# %%
# 1st method
fig=plt.figure() #creates a figure
ax=fig.add_subplot() #adds some axes
x=[1,2,3,4]
y=[11,22,33,44]
ax.plot(x,y);

# %%
#2nd method
fig=plt.figure()#creates a figure
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y) 
plt.show()

# %%
#3rd Method(Recommended)
fig,ax=plt.subplots()
ax.plot([3,5,7,9],[50,100,200,250])#add some data
type(fig),type(ax);

# %% [markdown]
# ## #Matplotlib example workflow

# %%
#0.import matplotlib and get it ready for plotting in jupyter.
# %matplotlib inline
import matplotlib.pyplot as plt



#1.prepare data
x=[1,2,3,4]
y=[11,22,33,44]


#2.set up plot
fig,ax=plt.subplots(figsize=(10,10)) #width,height


#3.plot data
ax.plot(x,y)


#4.Customize plot
ax.set(title="Simple plt",xlabel="x-axis",ylabel="y-axis")


#5.save and show(you save the whole figure)
fig.savefig("images/sample-plot.png")

# %% [markdown]
# # Making figures with NumPy arrays
#  we want:
#  * Line plot
#  * Scatter plot
#  * Bar plot
#  * Histogram
#  * Subplots

# %%
import numpy as np

# %%
#create some data
x=np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
 x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a line plot
fig,ax=plt.subplots()
ax.plot(x,x**2)
plt.show()

# %%
#Use same data to make a scatter
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x));

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.tan(x));

# %%
#Make a plot from dictionary
nut_butter_prices={"Almond butter":10,
                  "Peanut butter":20,
                  "Cashew butter": 50}
fig,ax=plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax.set(title="Dan's Nut Butter Store",xlabel="Available Butter ",ylabel="Price($)")
plt.show()

# %%
#TO plot data from a list..
fig,ax=plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()));

# %%
#Make some data
x=np.random.randn(1000)
x
# Out:
# array([ 5.05742584e-01, -1.14477641e-01, -2.10111379e+00,  1.19175488e+00,
#        -5.82374049e-02, -3.73478346e-01,  1.02485283e-01, -9.08038891e-02,
#         3.50854839e-01, -1.58566997e+00,  4.42386246e-01,  9.41157946e-02,
#         1.33215643e-01,  7.34602978e-01, -2.93512753e-01, -3.03537344e-01,
#        -1.05607213e+00, -1.07716129e+00,  5.09222126e-01, -3.30564341e-02,
#         8.85622348e-01,  8.89083723e-01,  4.17023935e-01, -1.31655837e+00,
#        -2.97541845e-01,  1.90325421e+00,  6.76925612e-01, -3.86568067e-01,
#        -1.55859487e-01,  7.46735712e-01, -1.40219996e+00,  5.73666597e-01,
#        -1.48695835e+00, -9.21395630e-01, -3.94593828e-01,  1.16238951e+00,
#        -5.09759211e-01, -8.81287119e-02, -4.97261175e-01, -1.61784967e+00,
#         2.27711015e-01,  5.04365861e-01,  1.48770414e+00,  9.30475332e-01,
#        -2.31818792e+00, -3.81638656e-01, -1.74612673e+00, -1.03354399e+00,
# ...

# %%
#Make some data for histogram and plot it
fig,ax=plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options for subplot

# %%
#subplot Option 1

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))


#plot to each different axis
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# Subplot option 2
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))

# Plot to each different index
ax[0,0].plot(x,x/2);

ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# # plotting from pandas dataframes

# %%
import pandas as pd

# %%
#Make a dataframe

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts=pd.Series(np.random.randn(1000),index=pd.date_range("25/4/2022",periods=1000))
ts=ts.cumsum()

# %%
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]',"")
# Out:
# C:\Users\Ankit Kumar\AppData\Local\Temp\ipykernel_15428\899491785.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]',"")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
#remove last two zeroes
car_sales["Price"]=car_sales["Price"].str[:-2]
type(car_sales["Price"][0])
# Out:
# str

# %%
car_sales["sales_date"]=pd.date_range("25/4/2022",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price sales_date
# 0  Toyota  White         150043      4   4000 2022-04-25
# 1   Honda    Red          87899      4   5000 2022-04-26
# 2  Toyota   Blue          32549      3   7000 2022-04-27
# 3     BMW  Black          11179      5  22000 2022-04-28
# 4  Nissan  White         213095      4   3500 2022-04-29
# 5  Toyota  Green          99213      4   4500 2022-04-30
# 6   Honda   Blue          45698      4   7500 2022-05-01
# 7   Honda   Blue          54738      4   7000 2022-05-02
# 8  Toyota  White          60000      4   6250 2022-05-03
# 9  Nissan  White          31600      4   9700 2022-05-04

# %%
car_sales["total_sales"]=car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price sales_date  total_sales
# 0  Toyota  White         150043      4   4000 2022-04-25         4000
# 1   Honda    Red          87899      4   5000 2022-04-26         9000
# 2  Toyota   Blue          32549      3   7000 2022-04-27        16000
# 3     BMW  Black          11179      5  22000 2022-04-28        38000
# 4  Nissan  White         213095      4   3500 2022-04-29        41500
# 5  Toyota  Green          99213      4   4500 2022-04-30        46000
# 6   Honda   Blue          45698      4   7500 2022-05-01        53500
# 7   Honda   Blue          54738      4   7000 2022-05-02        60500
# 8  Toyota  White          60000      4   6250 2022-05-03        66750
# 9  Nissan  White          31600      4   9700 2022-05-04        76450

# %%
#to draw a pie chart
fig,ax=plt.subplots()
ax.pie(car_sales["Price"],labels=car_sales["Make"],radius=2);

# %%
car_sales.plot(x="sales_date",y="total_sales");

# %%
#plot scatter plot with price column as numeric
car_sales["Price"]=car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
 type(car_sales["Price"][0])
# Out:
# numpy.int32

# %%
x=np.random.randn(10,4)
x




#Turn it into a dataframe
df=pd.DataFrame(x,columns=["a","b","c","d"])
df
# Out:
#           a         b         c         d
# 0  0.535595 -1.768880  0.906786  0.463068
# 1 -0.281444  0.344875  0.427349 -1.108010
# 2  0.720955  0.265693 -0.335406  0.930809
# 3 -0.111566 -0.496430  0.087926 -1.605602
# 4 -1.703897 -0.734290 -0.203131  0.075209
# 5  1.294013  0.058310 -0.353419  0.144139
# 6  0.755427  0.311000 -1.134246 -0.735129
# 7  0.799664 -0.851674 -0.812764 -1.214717
# 8  0.637325  0.174121 -0.529050 -0.686830
# 9  0.414756  0.074164 -0.529420  1.085897

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price sales_date  total_sales
# 0  Toyota  White         150043      4   4000 2022-04-25         4000
# 1   Honda    Red          87899      4   5000 2022-04-26         9000
# 2  Toyota   Blue          32549      3   7000 2022-04-27        16000
# 3     BMW  Black          11179      5  22000 2022-04-28        38000
# 4  Nissan  White         213095      4   3500 2022-04-29        41500
# 5  Toyota  Green          99213      4   4500 2022-04-30        46000
# 6   Honda   Blue          45698      4   7500 2022-05-01        53500
# 7   Honda   Blue          54738      4   7000 2022-05-02        60500
# 8  Toyota  White          60000      4   6250 2022-05-03        66750
# 9  Nissan  White          31600      4   9700 2022-05-04        76450

# %%
#car_sales.plot.bar(x="Make",y="Odometer (KM)");


car_sales.plot(x="Make",y="Odometer (KM)",kind="bar")
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot.hist(bins=30);

# %%
car_sales["Price"].hist();

# %%
heart=pd.read_csv("heart-disease.csv")

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#create a histogram of age
heart["age"].plot.hist(bins=50);

# %%
heart.plot.hist(figsize=(10,10),subplots=True);

# %%
heart["chol"].plot.barh(figsize=(10,90));

# %% [markdown]
# ## which one should you use?(pyplot vs matplotlib OO method?)
# * When plotting something quickly,okay to use pyplot method
# * When plotting something more advanced,use the OO method

# %%
over_50=heart[heart["age"]>50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
#g=np.arange(0,208)
over_50.plot(kind="scatter",x="age",y="chol",c="target");

# %%
#OO method mixed with pyplot

fix,ax=plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            ax=ax);
#ax.set_xlim([45,100])

# %%
#OO method from scratch
fig,ax=plt.subplots(figsize=(10,6))
#Plot the data
scatter=ax.scatter(x=over_50["age"],
                   y=over_50["chol"],
                  c=over_50["target"]);
#customize the plot
ax.set(title="heart disease and cholestrol levels",
      xlabel="Age",
      ylabel="cholestrol");
#Add a legend
ax.legend(*scatter.legend_elements(),title="Target");

#Add a horizontal line
ax.axhline(over_50["chol"].mean(),linestyle="--");
ax.axvline(over_50["age"].mean(),linestyle="dotted");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#subplot of chol,age,thalach
fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10));

#add data to ax0
scatter=ax0.scatter(x=over_50["age"],
                    y=over_50["chol"],
                   c=over_50["target"]);
#customize ax0
ax0.set(title="heart disease and cholestrol level",
       xlabel="Age",
       ylabel="Cholestrol");
#add a legend
ax0.legend(*scatter.legend_elements(),title="Target");
#add a meanline
ax0.axhline(over_50["chol"].mean(),linestyle="dotted");
ax0.axvline(over_50["age"].mean(),linestyle="dotted");


#add data to ax1 
scatter=ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                   c=over_50["target"]);
#customize ax1
ax1.set(title="heart disease and max heart rate",
       xlabel="Age",
       ylabel="thalach");
#add a legend
ax1.legend(*scatter.legend_elements(),title="Target");
#add a meanline
ax1.axhline(over_50["thalach"].mean(),linestyle="dotted");
ax1.axvline(over_50["age"].mean(),linestyle="dotted");

#Add a title to the whole figure
fig.suptitle("HEART DISEASE ANALYSIS",fontsize=16,fontweight="bold",color="purple")
# Out:
# Text(0.5, 0.98, 'HEART DISEASE ANALYSIS')

# %%
#Customizing Matplotlib plots
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %%
plt.style.use('ggplot')
car_sales.Price.plot();

# %%
df
# Out:
#           a         b         c         d
# 0  0.535595 -1.768880  0.906786  0.463068
# 1 -0.281444  0.344875  0.427349 -1.108010
# 2  0.720955  0.265693 -0.335406  0.930809
# 3 -0.111566 -0.496430  0.087926 -1.605602
# 4 -1.703897 -0.734290 -0.203131  0.075209
# 5  1.294013  0.058310 -0.353419  0.144139
# 6  0.755427  0.311000 -1.134246 -0.735129
# 7  0.799664 -0.851674 -0.812764 -1.214717
# 8  0.637325  0.174121 -0.529050 -0.686830
# 9  0.414756  0.074164 -0.529420  1.085897

# %%
ax=df.plot(kind='bar')
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
#customize our plot with the set() method
ax=df.plot(kind='bar')
ax.set(title="Random Number Graph from Dataframe",
      xlabel="Row number",
      ylabel="Random number")
#Make the legend visible
ax.legend().set_visible(True)

# %%
plt.style.use('seaborn')

#OO method from scratch
fig,ax=plt.subplots(figsize=(10,6))
#Plot the data
scatter=ax.scatter(x=over_50["age"],
                   y=over_50["chol"],
                  c=over_50["target"],
                  cmap="winter_r");# this changes the colour schemes
#customize the plot
ax.set(title="heart disease and cholestrol levels",
      xlabel="Age",
      ylabel="cholestrol");
#Add a legend
ax.legend(*scatter.legend_elements(),title="Target");

#Add a horizontal line
ax.axhline(over_50["chol"].mean(),linestyle="dashdot");
ax.axvline(over_50["age"].mean(),linestyle="dotted");

# %% [markdown]
# ## This plot shows some information about the heart disease

# %%
#customizing the y and x axis limitations


fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10));

#add data to ax0
scatter=ax0.scatter(x=over_50["age"],
                    y=over_50["chol"],
                   c=over_50["target"],
                   cmap="winter");
#customize ax0
ax0.set(title="heart disease and cholestrol level",
       xlabel="Age",
       ylabel="Cholestrol");
# Change the x-axis limits
ax0.set_xlim([50,80])
#add a legend
ax0.legend(*scatter.legend_elements(),title="Target");
#add a meanline
ax0.axhline(over_50["chol"].mean(),linestyle="dotted");
ax0.axvline(over_50["age"].mean(),linestyle="dotted");


#add data to ax1 
scatter=ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                   c=over_50["target"],
                   cmap="summer");
#customize ax1
ax1.set(title="heart disease and max heart rate",
       xlabel="Age",
       ylabel="thalach");
#change ax1 x axis limits
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])
#add a legend
ax1.legend(*scatter.legend_elements(),title="Target");
#add a meanline
ax1.axhline(over_50["thalach"].mean(),linestyle="dotted");
ax1.axvline(over_50["age"].mean(),linestyle="dotted");

#Add a title to the whole figure
fig.suptitle("HEART DISEASE ANALYSIS",fontsize=16,fontweight="bold",color="purple")
# Out:
# Text(0.5, 0.98, 'HEART DISEASE ANALYSIS')

# %%
fig

# %%
fig.savefig("images/heart disease-analysis plot saved with code.png")
